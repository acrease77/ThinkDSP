# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas
import scipy.signal

PI2 = 2 * math.pi

# %precision 3
# %matplotlib inline

# %%
class ComplexSinusoid(thinkdsp.Sinusoid):
    """Represents a complex exponential signal."""
    
    def evaluate(self, ts):
        """Evaluates the signal at the given times.

        ts: float array of times
        
        returns: float wave array
        """
        print(ts)
        i = complex(0, 1)
        phases = PI2 * self.freq * ts + self.offset
        print(phases)
        ys = self.amp * numpy.exp(i * phases)
        return ys

# %%
signal = ComplexSinusoid(freq=440, amp=0.7, offset=1.1)
wave = signal.make_wave(duration=1, framerate=4)
# Out:
# [ 0.    0.25  0.5   0.75]
# [  1.100e+00   6.923e+02   1.383e+03   2.075e+03]

# %%
wave * complex(-1.5,-.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-70377a310d75> in <module>()
# ----> 1 wave * complex(-1.5,-.5)
#
# /home/acrease77/SigSys/ThinkDSP/code/thinkdsp.pyc in __mul__(self, other)
#     596         returns: Wave
#     597         """
# --> 598         if self.framerate != other.framerate:
#     599             raise ValueError('Wave convolution: framerates do not agree')
#     600
#
# AttributeError: 'complex' object has no attribute 'framerate'

# %%
parasigs=thinkdsp.ParabolicSignal()
squaresigs=thinkdsp.SquareSignal()
paraspecs = parasigs.make_wave(duration=.01,framerate=44100).make_spectrum()
sigspecs = squaresigs.make_wave(duration=.01,framerate=44100).make_spectrum()
totalspecs = paraspecs + sigspecs
totalspecs.plot()
paraspecs.plot()
sigspecs.plot()

# %%
totalspecs.make_wave().plot()
